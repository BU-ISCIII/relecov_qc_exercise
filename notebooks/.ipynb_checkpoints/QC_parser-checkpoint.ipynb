# %%
import pandas as pd

# %%
pd.read_excel('CONTROL CALIDAD-HERA COD_2129.xlsx',sheet_name="2. General", index_col=None, header=1)
# Out:
#          ID Email de contacto Fecha de envío Fecha de recepción  \
# 0  COD_2129   fegarcia@ugr.es     2021-12-21         2021-12-27
#
#   Fecha de emisión de resultados  \
# 0                     2022-01-21
#
#                                 Autores del análisis  Autor remitente
# 0  Federico García, Javier Pérez Florido, Adolfo ...  Federico García

# %%
pd.read_excel('CONTROL CALIDAD-HERA COD_2129.xlsx',sheet_name="3. Resultados", index_col=None, header=2)
# Out:
#           ID ID Muestra Protocolo diagnóstico SARS-CoV-2 Valor Ct PCR  \
# 0   COD_2101         #1                     Whole genome           25
# 1   COD_2101         #2                     Whole genome           23
# 2   COD_2101         #3                     Whole genome           29
# 3   COD_2101         #4                     Whole genome           25
# 4   COD_2101         #5                     Whole genome           27
# 5   COD_2109         #6                     Whole genome           31
# 6   COD_2109         #7                     Whole genome           36
# 7   COD_2109         #8                     Whole genome           21
# 8   COD_2109         #9                     Whole genome           23
# 9   COD_2109        #10                     Whole genome           29
# 10       NaN        NaN                              NaN        Gen N
#
#    Variante Asignación de Linaje  \
# 0     Alpha              B.1.1.7
# 1      Beta              B.1.351
# 2       19B                 A.28
# 3        Mu              B.1.621
# 4     Gamma                  P.1
# 5     Delta               AY.9.2
# 6         -                    -
# 7     Delta                AY.94
# 8     Delta                AY.94
# 9     Delta                AY.43
# 10      NaN                  NaN
#
#                                         Versión Pango  Read count  \
# 0   Pangolin 3.1.17 / PangoLEARN 2021-12-06 / pang...    393636.0
# 1   Pangolin 3.1.17 / PangoLEARN 2021-12-06 / pang...    427164.0
# 2   Pangolin 3.1.17 / PangoLEARN 2021-12-06 / pang...    248256.0
# 3   Pangolin 3.1.17 / PangoLEARN 2021-12-06 / pang...    348634.0
# 4   Pangolin 3.1.17 / PangoLEARN 2021-12-06 / pang...    418158.0
# 5   Pangolin 3.1.17 / PangoLEARN 2021-12-06 / pang...    380354.0
# 6                                                   -    270042.0
# 7   Pangolin 3.1.17 / PangoLEARN 2021-12-06 / pang...    223896.0
# 8   Pangolin 3.1.17 / PangoLEARN 2021-12-06 / pang...    339808.0
# 9   Pangolin 3.1.17 / PangoLEARN 2021-12-06 / pang...    315836.0
# 10                                                NaN         NaN
#
#     %QC filtered  %Reads host  %Reads virus  %Unmapped  % Genome > 10x  \
# 0         0.8816          NaN         99.97       0.95        0.990402
# 1         0.8932          NaN         99.98       0.31        0.996689
# 2         0.8962          NaN         99.98       1.95        0.982811
# 3         0.8958          NaN         99.98       0.96        0.990101
# 4         0.8998          NaN         99.99       0.93        0.990804
# 5         0.8960          NaN         99.99       1.95        0.980236
# 6         0.8657          NaN         99.96      90.78        0.092165
# 7         0.8960          NaN         99.98       0.97        0.990135
# 8         0.8858          NaN         99.98       0.96        0.990135
# 9         0.8514          NaN         99.98       0.95        0.989867
# 10           NaN          NaN           NaN        NaN             NaN
#
#     Mean depth of coverage value     %Ns  Number of variants (AF > 75%)  \
# 0                          690.0   0.724                           42.0
# 1                          740.0   0.097                           28.0
# 2                          480.0   1.400                           24.0
# 3                          635.0   0.668                           38.0
# 4                          735.0   0.690                           40.0
# 5                          637.0   1.642                           36.0
# 6                          182.0  90.330                            1.0
# 7                          434.0   0.681                           45.0
# 8                          611.0   0.748                           45.0
# 9                          563.0   0.741                           43.0
# 10                           NaN     NaN                            NaN
#
#     Numer of variants with effect (missense, frameshit, stop codon)  \
# 0                                                30.0
# 1                                                20.0
# 2                                                13.0
# 3                                                22.0
# 4                                                27.0
# 5                                                24.0
# 6                                                 1.0
# 7                                                30.0
# 8                                                30.0
# 9                                                30.0
# 10                                                NaN
#
#    Reference genome accession
# 0                  MN908947.3
# 1                  MN908947.3
# 2                  MN908947.3
# 3                  MN908947.3
# 4                  MN908947.3
# 5                  MN908947.3
# 6                  MN908947.3
# 7                  MN908947.3
# 8                  MN908947.3
# 9                  MN908947.3
# 10                        NaN

# %%
pd.read_excel('CONTROL CALIDAD-HERA COD_2129.xlsx',sheet_name="4. Datos de secuenciación ", index_col=None, header=1)
# Out:
#      LAB ID     Sample ID Sequencing date Enrichment protocol  \
# 0  COD_2129   COD_2101_#1      2021-12-30            Amplicon
# 1  COD_2129   COD_2101_#2      2021-12-30            Amplicon
# 2  COD_2129   COD_2101_#3      2021-12-30            Amplicon
# 3  COD_2129   COD_2101_#4      2021-12-30            Amplicon
# 4  COD_2129   COD_2101_#5      2021-12-30            Amplicon
# 5  COD_2129   COD_2101_#6      2021-12-30            Amplicon
# 6  COD_2129   COD_2101_#7      2021-12-30            Amplicon
# 7  COD_2129   COD_2101_#8      2021-12-30            Amplicon
# 8  COD_2129   COD_2101_#9      2021-12-30            Amplicon
# 9  COD_2129  COD_2101_#10      2021-12-30            Amplicon
#
#    if enrichment protocol is other, specify Amplicon protocol  \
# 0                                       NaN             ARTIC
# 1                                       NaN             ARTIC
# 2                                       NaN             ARTIC
# 3                                       NaN             ARTIC
# 4                                       NaN             ARTIC
# 5                                       NaN             ARTIC
# 6                                       NaN             ARTIC
# 7                                       NaN             ARTIC
# 8                                       NaN             ARTIC
# 9                                       NaN             ARTIC
#
#    if amplicon protocol if other, especify  Amplicon version  \
# 0                                      NaN                 3
# 1                                      NaN                 3
# 2                                      NaN                 3
# 3                                      NaN                 3
# 4                                      NaN                 3
# 5                                      NaN                 3
# 6                                      NaN                 3
# 7                                      NaN                 3
# 8                                      NaN                 3
# 9                                      NaN                 3
#
#           Library preparation kit  if library prepation is other, specify  \
# 0  Illumina DNA Prep Tagmentation                                     NaN
# 1  Illumina DNA Prep Tagmentation                                     NaN
# 2  Illumina DNA Prep Tagmentation                                     NaN
# 3  Illumina DNA Prep Tagmentation                                     NaN
# 4  Illumina DNA Prep Tagmentation                                     NaN
# 5  Illumina DNA Prep Tagmentation                                     NaN
# 6  Illumina DNA Prep Tagmentation                                     NaN
# 7  Illumina DNA Prep Tagmentation                                     NaN
# 8  Illumina DNA Prep Tagmentation                                     NaN
# 9  Illumina DNA Prep Tagmentation                                     NaN
#
#    ... Unnamed: 1014 Unnamed: 1015  Unnamed: 1016  Unnamed: 1017  \
# 0  ...           NaN           NaN            NaN            NaN
# 1  ...           NaN           NaN            NaN            NaN
# 2  ...           NaN           NaN            NaN            NaN
# 3  ...           NaN           NaN            NaN            NaN
# 4  ...           NaN           NaN            NaN            NaN
# 5  ...           NaN           NaN            NaN            NaN
# 6  ...           NaN           NaN            NaN            NaN
# 7  ...           NaN           NaN            NaN            NaN
# 8  ...           NaN           NaN            NaN            NaN
# 9  ...           NaN           NaN            NaN            NaN
#
#   Unnamed: 1018  Unnamed: 1019  Unnamed: 1020  Unnamed: 1021  Unnamed: 1022  \
# 0           NaN            NaN            NaN            NaN            NaN
# 1           NaN            NaN            NaN            NaN            NaN
# 2           NaN            NaN            NaN            NaN            NaN
# 3           NaN            NaN            NaN            NaN            NaN
# 4           NaN            NaN            NaN            NaN            NaN
# 5           NaN            NaN            NaN            NaN            NaN
# 6           NaN            NaN            NaN            NaN            NaN
# 7           NaN            NaN            NaN            NaN            NaN
# 8           NaN            NaN            NaN            NaN            NaN
# 9           NaN            NaN            NaN            NaN            NaN
#
#    Unnamed: 1023
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
#
# [10 rows x 1024 columns]

# %%
pd.read_excel('CONTROL CALIDAD-HERA COD_2129.xlsx',sheet_name="5. Datos  Bioinformaticos", index_col=None, header=1)
# Out:
#          ID Sample ID Bioinformatic protocol  \
# 0  COD_2129        #1     nf-core/viralrecon
# 1  COD_2129        #2     nf-core/viralrecon
# 2  COD_2129        #3     nf-core/viralrecon
# 3  COD_2129        #4     nf-core/viralrecon
# 4  COD_2129        #5     nf-core/viralrecon
# 5  COD_2129        #6     nf-core/viralrecon
# 6  COD_2129        #7     nf-core/viralrecon
# 7  COD_2129        #8     nf-core/viralrecon
# 8  COD_2129        #9     nf-core/viralrecon
# 9  COD_2129       #10     nf-core/viralrecon
#
#    if bioinformatic protocol is other, specify Bioinformatic protocol version  \
# 0                                          NaN                          1.1.0
# 1                                          NaN                          1.1.0
# 2                                          NaN                          1.1.0
# 3                                          NaN                          1.1.0
# 4                                          NaN                          1.1.0
# 5                                          NaN                          1.1.0
# 6                                          NaN                          1.1.0
# 7                                          NaN                          1.1.0
# 8                                          NaN                          1.1.0
# 9                                          NaN                          1.1.0
#
#   Commercial/open-source/both Preprocessing  if preprocessing other  \
# 0                 open-source         fastp                     NaN
# 1                 open-source         fastp                     NaN
# 2                 open-source         fastp                     NaN
# 3                 open-source         fastp                     NaN
# 4                 open-source         fastp                     NaN
# 5                 open-source         fastp                     NaN
# 6                 open-source         fastp                     NaN
# 7                 open-source         fastp                     NaN
# 8                 open-source         fastp                     NaN
# 9                 open-source         fastp                     NaN
#
#                                 Preprocessing params       Mapping  ...  \
# 0  --detect_adapter_for_pe --cut_front --cut_tail...  bowtie 2.4.1  ...
# 1  --detect_adapter_for_pe --cut_front --cut_tail...  bowtie 2.4.1  ...
# 2  --detect_adapter_for_pe --cut_front --cut_tail...  bowtie 2.4.1  ...
# 3  --detect_adapter_for_pe --cut_front --cut_tail...  bowtie 2.4.1  ...
# 4  --detect_adapter_for_pe --cut_front --cut_tail...  bowtie 2.4.1  ...
# 5  --detect_adapter_for_pe --cut_front --cut_tail...  bowtie 2.4.1  ...
# 6  --detect_adapter_for_pe --cut_front --cut_tail...  bowtie 2.4.1  ...
# 7  --detect_adapter_for_pe --cut_front --cut_tail...  bowtie 2.4.1  ...
# 8  --detect_adapter_for_pe --cut_front --cut_tail...  bowtie 2.4.1  ...
# 9  --detect_adapter_for_pe --cut_front --cut_tail...  bowtie 2.4.1  ...
#
#    Assembly params Variant Calling if variant calling other  \
# 0              NaN      ivar 1.2.2                      NaN
# 1              NaN      ivar 1.2.2                      NaN
# 2              NaN      ivar 1.2.2                      NaN
# 3              NaN      ivar 1.2.2                      NaN
# 4              NaN      ivar 1.2.2                      NaN
# 5              NaN      ivar 1.2.2                      NaN
# 6              NaN      ivar 1.2.2                      NaN
# 7              NaN      ivar 1.2.2                      NaN
# 8              NaN      ivar 1.2.2                      NaN
# 9              NaN      ivar 1.2.2                      NaN
#
#    Variant Calling params             Consensus if consensus other  \
# 0       -q 20 -t 25 -m 10  ivar consensus 1.2.2                NaN
# 1       -q 20 -t 25 -m 10  ivar consensus 1.2.2                NaN
# 2       -q 20 -t 25 -m 10  ivar consensus 1.2.2                NaN
# 3       -q 20 -t 25 -m 10  ivar consensus 1.2.2                NaN
# 4       -q 20 -t 25 -m 10  ivar consensus 1.2.2                NaN
# 5       -q 20 -t 25 -m 10  ivar consensus 1.2.2                NaN
# 6       -q 20 -t 25 -m 10  ivar consensus 1.2.2                NaN
# 7       -q 20 -t 25 -m 10  ivar consensus 1.2.2                NaN
# 8       -q 20 -t 25 -m 10  ivar consensus 1.2.2                NaN
# 9       -q 20 -t 25 -m 10  ivar consensus 1.2.2                NaN
#
#        Consensus criteria Linage identification  \
# 0  -q 20 -t 25 -m 10 -n N       Pangolin 3.1.17
# 1  -q 20 -t 25 -m 10 -n N       Pangolin 3.1.17
# 2  -q 20 -t 25 -m 10 -n N       Pangolin 3.1.17
# 3  -q 20 -t 25 -m 10 -n N       Pangolin 3.1.17
# 4  -q 20 -t 25 -m 10 -n N       Pangolin 3.1.17
# 5  -q 20 -t 25 -m 10 -n N       Pangolin 3.1.17
# 6  -q 20 -t 25 -m 10 -n N       Pangolin 3.1.17
# 7  -q 20 -t 25 -m 10 -n N       Pangolin 3.1.17
# 8  -q 20 -t 25 -m 10 -n N       Pangolin 3.1.17
# 9  -q 20 -t 25 -m 10 -n N       Pangolin 3.1.17
#
#   if lineage identification other  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
#
#    Quality control metrics (sample discard criteria)
# 0                     Reference genome covered < 95%
# 1                     Reference genome covered < 95%
# 2                     Reference genome covered < 95%
# 3                     Reference genome covered < 95%
# 4                     Reference genome covered < 95%
# 5                     Reference genome covered < 95%
# 6                     Reference genome covered < 95%
# 7                     Reference genome covered < 95%
# 8                     Reference genome covered < 95%
# 9                     Reference genome covered < 95%
#
# [10 rows x 24 columns]

# %%
import seaborn as sns
import pandas as pd

sheet1, sheet2 = None, None
with pd.ExcelFile(
    "/home/erika.kvalem/Documents/Relecov/relecov_qc_exercise/files/QC_final.xlsx"
) as reader:
    df = pd.read_excel(reader, sheet_name="resultados")
    # sheet2 = pd.read_excel(reader, sheet_name='Sheet2')


#print(sheet1["var_readcount"])

"""
sns.set_theme(style="whitegrid")

tips = sns.load_dataset("tips")

#ax = sns.boxplot(x=tips["total_bill"])

ax = sns.boxplot(x="day", y="total_bill", data=tips)
"""
# Out:
# '\nsns.set_theme(style="whitegrid")\n\ntips = sns.load_dataset("tips")\n\n#ax = sns.boxplot(x=tips["total_bill"])\n\nax = sns.boxplot(x="day", y="total_bill", data=tips)\n'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                400 non-null    object
#  1   Sample ID                         400 non-null    object
#  2   Protocolo diagnostico SARS-CoV-2  390 non-null    object
#  3   var_protocolo_diagnostico         390 non-null    object
#  4   Variante                          355 non-null    object
#  5   Asignacion de Linaje              384 non-null    object
#  6   Version Pango                     394 non-null    object
#  7   Valor Ct PCR                      280 non-null    float64
#  8   Valor Ct N                        60 non-null     float64
#  9   Valor Ct ORF                      30 non-null     float64
#  10  Valor Ct S                        35 non-null     float64
#  11  var_readcount                     389 non-null    float64
#  12  var_qcfiltered                    253 non-null    float64
#  13  var_readhost                      228 non-null    float64
#  14  var_readsvirus                    352 non-null    float64
#  15  var_unmapped                      310 non-null    float64
#  16  var_QC>10x                        317 non-null    float64
#  17  var_mean_depth_coverage           378 non-null    float64
#  18  var_n_Ns                          337 non-null    float64
#  19  var_number_variants_75            252 non-null    float64
#  20  var_variantseffect                279 non-null    float64
#  21  var_referencegenomeaccession      389 non-null    object
# dtypes: float64(14), object(8)
# memory usage: 68.9+ KB

# %%
data = [df["ID"],df["Sample ID "], df["var_readcount"],df["var_qcfiltered"]]

headers = ["ID", "var_readcount","var_qcfiltered "]

df2 = pd.concat(data, axis=1, keys=headers)

# %%
df2.iloc[0:10,:]
# Out:
#          ID var_readcount  var_qcfiltered
# 0  COD_2102            #1         682115.0
# 1  COD_2102            #2         680035.0
# 2  COD_2102            #3         591253.0
# 3  COD_2102            #4         525910.0
# 4  COD_2102            #5         247292.0
# 5  COD_2102            #6         431544.0
# 6  COD_2102            #7           3678.0
# 7  COD_2102            #8         477610.0
# 8  COD_2102            #9         466440.0
# 9  COD_2102           #10        1187986.0

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

ax = sns.boxplot(y=df2["var_readcount"])
#ax = sns.boxplot(x="ID", y="var_readcount", data=df2)

# %%
del df2
